# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd
from sklearn.cluster import KMeans

# %%
iris=load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df=pd.DataFrame(iris.data ,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['Flower']=iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Flower
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.drop(['sepal length (cm)','sepal width (cm)'],axis='columns',inplace=True)
df.head()
# Out:
#    petal length (cm)  petal width (cm)  Flower
# 0                1.4               0.2       0
# 1                1.4               0.2       0
# 2                1.3               0.2       0
# 3                1.5               0.2       0
# 4                1.4               0.2       0

# %%
# %matplotlib inline
plt.scatter(df['petal width (cm)'],df['petal length (cm)'],color='red',marker='+')

# %%
sse=[]
k_rng=range(1,10)
for i in k_rng:
    km=KMeans(n_clusters=i)
    km.fit(df[['petal length (cm)','petal width (cm)']])
    sse.append(km.inertia_)

sse
# Out:
# c:\Users\Shoaib Nisar\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Shoaib Nisar\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Shoaib Nisar\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Shoaib Nisar\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Shoaib Nisar\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Shoaib Nisar\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Shoaib Nisar\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Shoaib Nisar\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\Shoaib Nisar\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [550.8953333333334,
#  86.39021984551397,
#  31.371358974358984,
#  20.2996078034854,
#  14.067949656750573,
#  11.130143401561249,
#  9.819095680377414,
#  7.945363530473504,
#  6.456494541406307]

# %%
# %matplotlib inline
plt.xlabel('Clusters')
plt.ylabel('SSE')
plt.plot(k_rng,sse)
plt.show()

# %%
km=KMeans(n_clusters=3)
y_predicted=km.fit_predict(df[['petal length (cm)','petal width (cm)']])
df['target']=y_predicted
df.head()
# Out:
# c:\Users\Shoaib Nisar\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#    petal length (cm)  petal width (cm)  Flower  target
# 0                1.4               0.2       0       1
# 1                1.4               0.2       0       1
# 2                1.3               0.2       0       1
# 3                1.5               0.2       0       1
# 4                1.4               0.2       0       1

# %%
df1=df[df.target==0]
df2=df[df.target==1]
df3=df[df.target==2]
df3
# Out:
#      petal length (cm)  petal width (cm)  Flower  target
# 77                 5.0               1.7       1       2
# 83                 5.1               1.6       1       2
# 100                6.0               2.5       2       2
# 101                5.1               1.9       2       2
# 102                5.9               2.1       2       2
# 103                5.6               1.8       2       2
# 104                5.8               2.2       2       2
# 105                6.6               2.1       2       2
# 107                6.3               1.8       2       2
# 108                5.8               1.8       2       2
# 109                6.1               2.5       2       2
# 110                5.1               2.0       2       2
# 111                5.3               1.9       2       2
# 112                5.5               2.1       2       2
# 113                5.0               2.0       2       2
# 114                5.1               2.4       2       2
# 115                5.3               2.3       2       2
# 116                5.5               1.8       2       2
# 117                6.7               2.2       2       2
# 118                6.9               2.3       2       2
# 120                5.7               2.3       2       2
# 121                4.9               2.0       2       2
# 122                6.7               2.0       2       2
# 124                5.7               2.1       2       2
# 125                6.0               1.8       2       2
# 128                5.6               2.1       2       2
# 129                5.8               1.6       2       2
# 130                6.1               1.9       2       2
# 131                6.4               2.0       2       2
# 132                5.6               2.2       2       2
# 133                5.1               1.5       2       2
# 134                5.6               1.4       2       2
# 135                6.1               2.3       2       2
# 136                5.6               2.4       2       2
# 137                5.5               1.8       2       2
# 139                5.4               2.1       2       2
# 140                5.6               2.4       2       2
# 141                5.1               2.3       2       2
# 142                5.1               1.9       2       2
# 143                5.9               2.3       2       2
# 144                5.7               2.5       2       2
# 145                5.2               2.3       2       2
# 146                5.0               1.9       2       2
# 147                5.2               2.0       2       2
# 148                5.4               2.3       2       2
# 149                5.1               1.8       2       2

# %%
km.cluster_centers_
# Out:
# array([[4.29259259, 1.35925926],
#        [1.462     , 0.246     ],
#        [5.62608696, 2.04782609]])

# %%
# %matplotlib inline
plt.scatter(df1['petal length (cm)'],df1['petal width (cm)'],color='blue')
plt.scatter(df2['petal length (cm)'],df2['petal width (cm)'],color='black')
plt.scatter(df3['petal length (cm)'],df3['petal width (cm)'],color='red')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='+')
